# %% [markdown]
# # 03 Assess Static Resilience
#
# Run the static indicator demo and regenerate figures. The current static table is a real-data smoke test until real HydroATLAS and other source-derived indicators are merged.

# %%
# !python -m hydroreskit.cli validate-table data_work/yangtze_static_indicators.csv configs/indicator_schema.yml --unit-id-column HYBAS_ID

# %%
# !python -m hydroreskit.cli demo configs/yangtze_static_demo.yml

# %%
# !python scripts/make_demo_figures.py

# %%
import pandas as pd
scores = pd.read_csv('outputs/yangtze_static_scores.csv')
scores.head()
